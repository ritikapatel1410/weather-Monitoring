# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


'''
 * File Description:- Python program to find current weather details of any city using openweathermap api
 * 
 * Name                 Date            Changes
 * Ritika Patidar       16/07/20        Initial Version
'''
# import required modules 
import requests, json 
import openpyxl
import threading
# Enter your API key here 
api_key = "a74fc0f54eaf493d76d96a9c7782ff53"

# base_url variable to store url 
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Give city name 
city_name = "Ujjain"

# complete_url variable to store 
# complete url address 
complete_url = base_url + "q=" + city_name + "&appid=" + api_key
#print(complete_url)

# get method of requests module 
# return response object 
def weather_monitor():
    threading.Timer(10.0, weather_monitor).start()
    response = requests.get(complete_url) 

    # json method of response object 
    # convert json format data into 
    # python format data 
    x = response.json() 
    #print(x)

    # Now x contains list of nested dictionaries 
    # Check the value of "cod" key is equal to 
    # "404", means city is found otherwise, 
    # city is not found 
    if x["cod"] != "404": 

        # store the value of "main" 
        # key in variable y 
        y = x["main"] 

        # store the value corresponding 
        # to the "temp" key of y 
        current_temperature = y["temp"]-273.15 

        # store the value corresponding 
        # to the "humidity" key of y 
        current_humidiy = y["humidity"] 

        # store the value of "weather" 
        # key in variable z 
        z = x["id"] 
        Z=x["sys"]["country"]
        # store the value corresponding 
        # to the "description" key at 
        # the 0th index of z 

        # print following values 
        print(" Temperature (in celsius unit) = " +
                        str(current_temperature) +
            "\n humidity (in percentage) = " +
                        str(current_humidiy) +
            "\n city token = " +
                        str(Z)+str(z)) 

        #add excel sheet path here
        wbkName ="C:/Users/pcs/Desktop/Project Sample.xlsx"
        wbk1 = openpyxl.load_workbook(wbkName)
        wks = wbk1.active
        for wks in wbk.worksheets:
            wks.cell(row=11, column=1).value = str(Z)+str(z)
            wks.cell(row=11, column=2).value = current_temperature
            wks.cell(row=11, column=3).value = current_humidiy
            wks.cell(row=11, column=4).value = "C"
            wks.cell(row=11, column=5).value = 1
        wks.save(wbkName)
        wks.close
    else: 
        print(" City Not Found ") 

weather_monitor()
# Out:
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-1-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-29:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
#
#
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#  Temperature (in celsius unit) = 29.0
#  humidity (in percentage) = 70
#  city token = IN1253914
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-3-cd9de28b3d63> in <module>
#      90         print(" City Not Found ")
#      91
# ---> 92 weather_monitor()
#      93
#      94
#
# <ipython-input-3-cd9de28b3d63> in weather_monitor()
#      77         #add excel sheet path here
#      78         wbkName ="C:/Users/pcs/Desktop/Project Sample.xlsx"
# ---> 79         wbk1 = openpyxl.load_workbook(wbkName)
#      80         wks = wbk1.active
#      81         for wks in wbk.worksheets:
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     312     reader = ExcelReader(filename, read_only, keep_vba,
#     313                         data_only, keep_links)
# --> 314     reader.read()
#     315     return reader.wb
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in read(self)
#     277         self.read_theme()
#     278         apply_stylesheet(self.archive, self.wb)
# --> 279         self.read_worksheets()
#     280         self.parser.assign_names()
#     281         if not self.read_only:
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in read_worksheets(self)
#     225                 ws._rels = rels
#     226                 ws_parser = WorksheetReader(ws, fh, self.shared_strings, self.data_only)
# --> 227                 ws_parser.bind_all()
#     228
#     229             # assign any comments to cells
#
# ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py in bind_all(self)
#     424
#     425     def bind_all(self):
# --> 426         self.bind_cells()
#     427         self.bind_merged_cells()
#     428         self.bind_hyperlinks()
#
# ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py in bind_cells(self)
#     335
#     336     def bind_cells(self):
# --> 337         for idx, row in self.parser.parse():
#     338             for cell in row:
#     339                 style = self.ws.parent._cell_styles[cell['style_id']]
#
# ~\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py in parse(self)
#     140         it = iterparse(self.source)
#     141
# --> 142         for _, element in it:
#     143             tag_name = element.tag
#     144             if tag_name in dispatcher:
#
# ~\anaconda3\lib\xml\etree\ElementTree.py in iterator()
#    1222                 yield from pullparser.read_events()
#    1223                 # load event buffer
# -> 1224                 data = source.read(16 * 1024)
#    1225                 if not data:
#    1226                     break
#
# ~\anaconda3\lib\zipfile.py in read(self, n)
#     928         self._offset = 0
#     929         while n > 0 and not self._eof:
# --> 930             data = self._read1(n)
#     931             if n < len(data):
#     932                 self._readbuffer = data
#
# ~\anaconda3\lib\zipfile.py in _read1(self, n)
#     996             data = self._decompressor.unconsumed_tail
#     997             if n > len(data):
# --> 998                 data += self._read2(n - len(data))
#     999         else:
#    1000             data = self._read2(n)
#
# ~\anaconda3\lib\zipfile.py in _read2(self, n)
#    1031         self._compress_left -= len(data)
#    1032         if not data:
# -> 1033             raise EOFError
#    1034
#    1035         if self._decrypter is not None:
#
# EOFError:
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 81, in weather_monitor
#     for wks in wbk.worksheets:
# NameError: name 'wbk' is not defined
#
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-2-7ba9a23fb710>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
# ...
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-615:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-610:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-609:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-614:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
# Exception in thread Thread-620:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-616:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#
# Exception in thread Thread-618:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 314, in load_workbook
#     reader.read()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 279, in read
#     self.read_worksheets()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 227, in read_worksheets
#     ws_parser.bind_all()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 426, in bind_all
#     self.bind_cells()
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 337, in bind_cells
#     for idx, row in self.parser.parse():
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py", line 142, in parse
#     for _, element in it:
#   File "C:\Users\pcs\anaconda3\lib\xml\etree\ElementTree.py", line 1224, in iterator
#     data = source.read(16 * 1024)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 930, in read
#     data = self._read1(n)
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 998, in _read1
#     data += self._read2(n - len(data))
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1033, in _read2
#     raise EOFError
# EOFError
#  Temperature (in celsius unit) = 28.700000000000045
#  humidity (in percentage) = 76
#  city token = IN1253914
# Exception in thread Thread-624:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#  Temperature (in celsius unit) = 28.700000000000045
#  humidity (in percentage) = 76
#  city token = IN1253914
# Exception in thread Thread-625:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#  Temperature (in celsius unit) = 28.700000000000045
#  humidity (in percentage) = 76
#  city token = IN1253914
# Exception in thread Thread-626:
# Traceback (most recent call last):
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "C:\Users\pcs\anaconda3\lib\threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-3-cd9de28b3d63>", line 79, in weather_monitor
#     wbk1 = openpyxl.load_workbook(wbkName)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 313, in load_workbook
#     data_only, keep_links)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 124, in __init__
#     self.archive = _validate_archive(fn)
#   File "C:\Users\pcs\anaconda3\lib\site-packages\openpyxl\reader\excel.py", line 96, in _validate_archive
#     archive = ZipFile(filename, 'r')
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1258, in __init__
#     self._RealGetContents()
#   File "C:\Users\pcs\anaconda3\lib\zipfile.py", line 1325, in _RealGetContents
#     raise BadZipFile("File is not a zip file")
# zipfile.BadZipFile: File is not a zip file
#  Temperature (in celsius unit) = 28.700000000000045
#  humidity (in percentage) = 76
#  city token = IN1253914
#  Temperature (in celsius unit) = 28.700000000000045
#  humidity (in percentage) = 76
#  city token = IN1253914
